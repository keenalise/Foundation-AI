# %% [markdown]
# <a href="https://colab.research.google.com/github/keenalise/Foundation-AI/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('dataset.csv')

# %%
df
# Out:
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# 5          5    60  2020/12/06'       102       127       300.0
# 6          6    60  2020/12/07'       110       136       374.0
# 7          7   450  2020/12/08'       104       134       253.3
# 8          8    30  2020/12/09'       109       133       195.1
# 9          9    60  2020/12/10'        98       124       269.0
# 10        10    60  2020/12/11'       103       147       329.3
# 11        11    60  2020/12/12'       100       120       250.7
# 12        12    60  2020/12/12'       100       120       250.7
# 13        13    60  2020/12/13'       106       128       345.3
# ...

# %% [markdown]
# problem with our database

# %%
# return a DataFrame with no empty cells
# df.dropna() will remove empty cells but will not change the dataframe to be changed, use implace= true
import pandas as pd
df= pd.read_csv('dataset.csv')
new_df= df.dropna()
print(new_df.to_string())
# Out:
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# 5          5    60  2020/12/06'       102       127       300.0
# 6          6    60  2020/12/07'       110       136       374.0
# 7          7   450  2020/12/08'       104       134       253.3
# 8          8    30  2020/12/09'       109       133       195.1
# 9          9    60  2020/12/10'        98       124       269.0
# 10        10    60  2020/12/11'       103       147       329.3
# 11        11    60  2020/12/12'       100       120       250.7
# 12        12    60  2020/12/12'       100       120       250.7
# 13        13    60  2020/12/13'       106       128       345.3
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset.csv")
df.dropna(inplace = True)
print(df.to_string())
# Out:
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# 5          5    60  2020/12/06'       102       127       300.0
# 6          6    60  2020/12/07'       110       136       374.0
# 7          7   450  2020/12/08'       104       134       253.3
# 8          8    30  2020/12/09'       109       133       195.1
# 9          9    60  2020/12/10'        98       124       269.0
# 10        10    60  2020/12/11'       103       147       329.3
# 11        11    60  2020/12/12'       100       120       250.7
# 12        12    60  2020/12/12'       100       120       250.7
# 13        13    60  2020/12/13'       106       128       345.3
# ...

# %% [markdown]
# another way of handling null value, by replacing null values

# %%
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset.csv")
df.fillna(130, inplace= True)
print(df.to_string())
# Out:
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# 5          5    60  2020/12/06'       102       127       300.0
# 6          6    60  2020/12/07'       110       136       374.0
# 7          7   450  2020/12/08'       104       134       253.3
# 8          8    30  2020/12/09'       109       133       195.1
# 9          9    60  2020/12/10'        98       124       269.0
# 10        10    60  2020/12/11'       103       147       329.3
# 11        11    60  2020/12/12'       100       120       250.7
# 12        12    60  2020/12/12'       100       120       250.7
# 13        13    60  2020/12/13'       106       128       345.3
# ...

# %%
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset.csv")
df['Calories'].fillna(130, inplace=True)
df
# Out:
# <ipython-input-9-b92cc7efe0d6>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Calories'].fillna(130, inplace=True)
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# ...

# %%
#fill specific with mean, median or mode
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset.csv")
x= df["Calories"].mean()
df["Calories"].fillna(x, inplace=True)
df
# Out:
# <ipython-input-10-df1d07fabeb7>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace=True)
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01'       110       130       409.1
# 1          1    60  2020/12/02'       117       145       479.0
# 2          2    60  2020/12/03'       103       135       340.0
# 3          3    45  2020/12/04'       109       175       282.4
# 4          4    45  2020/12/05'       117       148       406.0
# ...

# %%
import pandas as pd
